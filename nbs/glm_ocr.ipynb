# %%
from ollama import chat

# %%
# Pass in the path to the image
#path = input('Please enter the path to the image: ')
path = '/Users/mvoong/Desktop/spark-symbiota-ml/transcription/data/new-england-samples/output/1039016550.jpeg'
#1039016550.jpeg
#1038919093.jpeg

response = chat(
  model='glm-ocr',
  messages=[
    {
      'role': 'user',
      'content': 'Extract the text from this image',
      #'content': 'Extract the collector, location, scientific name, event date, barcode, and institution code from this image output the result as a #JSON, if there is a value you are unsure of fill it with UNKNOWN',
      'images': [path],
    }
  ],
)

print(response.message.content)
# Out:
# Cymbidium muscarium FwP1924
#
# CONNECTICUT BOTANICAL SOCIETY
# CBS.29819
#
# HERBARIUM OF C. H. BISSELL.
#
# CONNECTICUT FLORA.
# Linaria Cymbalaria, K.
# Pasture ground along Willimantic River, Middham, Ct. Jul 8 1902
# COLLECTOR C. H. BISSELL.
